# %%
import os
import xarray as xr
import pandas as pd
import geopandas as gpd
import numpy as np
import shapely
#import cftime
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
import contextily as cx
import re

from pathlib import Path
import pathlib

# %%
country = 'GEO'

# %%
damage_data_path = Path('C://Users/snn490/OneDrive - Vrije Universiteit Amsterdam/WorldBank_Projects/SupplyChainECA/asset_damages/{}'.format(country))
fluvial_damage_data_path = damage_data_path / 'fluvial'

admin_path = Path('C:\\Users/snn490/OneDrive - Vrije Universiteit Amsterdam\WorldBank_Projects\SupplyChainECA\data\gadm')
figures_path = damage_data_path / damage_data_path.parents[1] / f"figures_{country}"
figures_path.mkdir(parents=True, exist_ok=True)

# %%
def calculate_risk(road_segment, damages_dict):
    damages_lst = [damages_dict[rp][damages_dict[rp]['osm_id'] == road_segment]['Partial destruction (0.5)'].iloc[0] for rp in [*damages_dict]]
    asset_dam_df = pd.DataFrame([1/rp for rp in [*damages_dict]]+[1,1e-10],damages_lst+[0, max(damages_lst)]).reset_index()
    asset_dam_df.columns = ['damage','prob']
    asset_dam_df = asset_dam_df.sort_values('prob',ascending=True).reset_index(drop=True)
    return np.trapz(asset_dam_df.damage.values,asset_dam_df.prob.values) #np.trapz(y,x)

def calculate_risk_vectorized(row):
    damages_lst = row.values
    rps = row.index
    if isinstance((row.index)[0], str): rps = [int(s) for con_rp in rps for s in re.findall(r'\d+', con_rp)]
    prob_values = np.array([1/rp for rp in rps] + [1, 1e-10]) # no design standard for earthquakes
    damage_values = np.append(damages_lst, [0, max(damages_lst)])
    sorted_indices = np.argsort(prob_values)
    prob_values = prob_values[sorted_indices]
    damage_values = damage_values[sorted_indices]
    return np.trapz(damage_values, prob_values)

def get_province(road_segment,subnational):
    try:
        column_names = subnational.columns
        if 'GID_3' in column_names:
            return subnational.loc[road_segment.geometry.intersects(subnational.geometry)].GID_3.values[0]
        elif 'GID_2' in column_names:
            return subnational.loc[road_segment.geometry.intersects(subnational.geometry)].GID_2.values[0]
    except:
        return None

def calculate_damage(road_segment):
    if road_segment.asset in ['primary','trunk','trunk_link','primary_link', 'motorway', 'motorway_link']:
        return road_segment["E7.12"]*0.18+road_segment["E7.7"]*0.39+road_segment["E7.11"]*0.43
    elif road_segment.asset in ['secondary','secondary_link']:
        return road_segment["E7.12"]*0.10+road_segment["E7.7"]*0.31+road_segment["E7.11"]*0.59
    elif road_segment.asset in ['tertiary','tertiary_link','road','residential','unclassified', 'track']:
        return road_segment["E7.12"]*0.09+road_segment["E7.7"]*0.25+road_segment["E7.11"]*0.66

def risk_ead_per_curve(damage_data_path):
    
    if 'fluvial' in str(damage_data_path.name):
        haz_rp_lst = [5, 20, 50, 75, 100, 200, 250, 500, 1000]
        fl_model = 'fluvial'
    
    #elif 'gar' in str(damage_data_path.name):
    #    haz_rp_lst = [250, 475, 975, 1500, 2475]
    #    fl_model = 'gar'
    
    #elif 'giri' in str(damage_data_path.name):
    #    haz_rp_lst = [250, 475, 975, 1500, 2475]
    #    eq_model = 'giri'
    
    # read parquets per return period
    road_types_lst = ['unclassified', 'primary', 'secondary', 'tertiary', 'residential', 
                                    'trunk', 'trunk_link',  'motorway','motorway_link',  'primary_link','secondary_link', 'tertiary_link','road', 'track' ]
    road_types_lst_remove = []
    assump_curves = ['E7.1', 'E7.6', 'E7.7', 'E7.8', 'E7.9', 'E7.10', 'E7.11', 'E7.12', 'E7.13', 'E7.14' ]
    #create df with all unique ID numbers, geometry and column ead
    ead_df = gpd.GeoDataFrame(columns=['osm_id', 'asset', 'geometry']+['ead_{}'.format(curve_id) for curve_id in assump_curves] 
                              +['ead_{}_overlay'.format(rp_trig) for rp_trig in haz_rp_lst], geometry='geometry')
    
    
    for road_type in road_types_lst:
        #create damages_dictionary containing damages for different return periods for asset type
        damages_dict = {key: pd.DataFrame() for key in haz_rp_lst}
        for rp in haz_rp_lst:
            damage_data_path_list = damage_data_path.iterdir()
            if eq_model == 'gem': 
                data_path = [path for path in damage_data_path_list if '_{}_road_{}'.format(rp,road_type) in str(path)]
            elif eq_model == 'gar':
                data_path = [path for path in damage_data_path_list if 'pga{}_road_{}'.format(rp,road_type) in str(path)]
            elif eq_model == 'giri':
                data_path = [path for path in damage_data_path_list if '_{}y_road_{}'.format(rp,road_type) in str(path)]
            
            if len(data_path) != 0:
                df = gpd.read_parquet(data_path[0])
                damages_dict[rp] = pd.concat([damages_dict[rp], df], ignore_index=True)  #create dictionary with the return period 
                for curve_id in assump_curves: damages_dict[rp] = damages_dict[rp].rename(columns={curve_id: f"{curve_id}_{rp}"}) # Rename the curve_id column in the damages_dict[rp] DataFrame
            else:
                print('No data for {}'.format(road_type))
                road_types_lst_remove.append(road_type)
    
        if road_type not in road_types_lst_remove:
            #calculate EAD
            osm_id_columns = [df['osm_id'] for df in damages_dict.values()] # Get all 'osm_id' columns from the DataFrames in damages_dict
            if all(df.equals(osm_id_columns[0]) for df in osm_id_columns): # Compare all 'osm_id' columns
                print("All osm_id columns are equal: True")
                temp_df = damages_dict[haz_rp_lst[0]][['osm_id', 'asset', 'geometry']]
                #temp_df = temp_df[0:2]
                print('These are the damages per return period for {}'.format(road_type))
                for curve_id in assump_curves:
                    temp_df_curve = temp_df[['osm_id']]
                    for rp in haz_rp_lst: #print(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]])
                        temp_df_curve = temp_df_curve.merge(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]], on='osm_id', how='left')
                    temp_df_curve.set_index('osm_id', inplace=True)
                    temp_df_curve.columns = temp_df_curve.columns.str.replace(f"{curve_id}_", '', regex=False)
                    temp_df.loc[:, ['ead_{}'.format(curve_id)]] = temp_df.apply(lambda row: calculate_risk_vectorized(temp_df_curve.loc[row['osm_id']]) if row['osm_id'] in temp_df_curve.index else np.nan, axis=1)
                    for rp in haz_rp_lst: print("The damage for a {} year return event following curve {}: {:,.2f}".format(rp, curve_id, temp_df_curve['{}'.format(rp)].sum()))
                ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period 
            
            else:
                temp_df = pd.concat([damages_dict[rp][['osm_id', 'asset', 'geometry']] for rp in damages_dict.keys()]).drop_duplicates(subset=['osm_id']) #merge dataframes into one and remove duplicates based on id_number 
                print("osm_id columns are not equal")
    
    ead_df = ead_df.to_crs(3857)
    
    for curve_id in assump_curves:
        print('This is the EAD for earthquakes using curve {}: {:,}'.format(curve_id, ead_df['ead_{}'.format(curve_id)].sum()))
        #print('This is the max EAD for road segment using curve {}: {:,}'.format(curve_id, ead_df['ead_{}'.format(curve_id)].max()))

    return ead_df

def risk_ead_combined(eq_damage_data_path):
    
    if 'gem' in str(eq_damage_data_path.name):
        haz_rp_lst = [475, 2475]
        eq_model = 'gem'
    
    elif 'gar' in str(eq_damage_data_path.name):
        haz_rp_lst = [250, 475, 975, 1500, 2475]
        eq_model = 'gar'
    
    elif 'giri' in str(eq_damage_data_path.name):
        haz_rp_lst = [250, 475, 975, 1500, 2475]
        eq_model = 'giri'
    
    # read parquets per return period
    road_types_lst = ['unclassified', 'primary', 'secondary', 'tertiary', 'residential', 
                                    'trunk', 'trunk_link',  'motorway','motorway_link',  'primary_link','secondary_link', 'tertiary_link','road', 'track' ]
    road_types_lst_remove = []
    assump_curves = ['E7.11','E7.7','E7.12']
    #create df with all unique ID numbers, geometry and column ead
    ead_df = gpd.GeoDataFrame(columns=['osm_id', 'asset', 'geometry']+['ead'] 
                              +['overlay_{}'.format(rp_trig) for rp_trig in haz_rp_lst], geometry='geometry')
    
    
    for road_type in road_types_lst:
        #create damages_dictionary containing damages for different return periods for asset type
        damages_dict = {key: pd.DataFrame() for key in haz_rp_lst}
        for rp in haz_rp_lst:
            damage_data_path_list = eq_damage_data_path.iterdir()  
            if eq_model == 'gem': 
                data_path = [path for path in damage_data_path_list if '_{}_road_{}'.format(rp,road_type) in str(path)]
            elif eq_model == 'gar':
                data_path = [path for path in damage_data_path_list if 'pga{}_road_{}'.format(rp,road_type) in str(path)]
            elif eq_model == 'giri':
                data_path = [path for path in damage_data_path_list if '_{}y_road_{}'.format(rp,road_type) in str(path)]
            
            if len(data_path) != 0:
                df = gpd.read_parquet(data_path[0])
                damages_dict[rp] = pd.concat([damages_dict[rp], df], ignore_index=True)  #create dictionary with the return period 
                #for curve_id in assump_curves: damages_dict[rp] = damages_dict[rp].rename(columns={curve_id: f"{curve_id}_{rp}"}) # Rename the curve_id column in the damages_dict[rp] DataFrame
            else:
                print('No data for {}'.format(road_type))
                road_types_lst_remove.append(road_type)
    
        if road_type not in road_types_lst_remove:
            #calculate EAD
            osm_id_columns = [df['osm_id'] for df in damages_dict.values()] # Get all 'osm_id' columns from the DataFrames in damages_dict
            if all(df.equals(osm_id_columns[0]) for df in osm_id_columns): # Compare all 'osm_id' columns
                print("All osm_id columns are equal: True")
                temp_df = damages_dict[haz_rp_lst[0]][['osm_id', 'asset', 'geometry']]
                #temp_df = temp_df[0:2]
                print('These are the damages per return period for {}'.format(road_type))
                temp_df_curve = temp_df[['osm_id']]
                for rp in haz_rp_lst: #print(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]])
                    damages_dict[rp]['total_damage_{}'.format(rp)] = damages_dict[rp].apply(lambda x: calculate_damage(x),axis=1)
                    temp_df_curve = temp_df_curve.merge(damages_dict[rp][['osm_id', f"total_damage_{rp}"]], on='osm_id', how='left')
                temp_df_curve.set_index('osm_id', inplace=True)
                #temp_df_curve.columns = temp_df_curve.columns.str.replace(f"total_damage_", '', regex=False)
                temp_df.loc[:, ['ead']] = temp_df.apply(lambda row: calculate_risk_vectorized(temp_df_curve.loc[row['osm_id']]) if row['osm_id'] in temp_df_curve.index else np.nan, axis=1)
                for rp in haz_rp_lst: print("The damage for a {} year return event following a combination of curves {}: {:,.2f}".format(rp, assump_curves, temp_df_curve['total_damage_{}'.format(rp)].sum()))
            ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period
    
            #fill in overlay columns
            for rp in haz_rp_lst:
                print('This is overlay dict for {} and {}'.format(rp, road_type))
                overlay_dict = damages_dict[rp].set_index('osm_id')['overlay'].to_dict()
                ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
                #ead_df['overlay_{}'.format(rp)] = ead_df['osm_id'].map(overlay_dict)
    
    ead_df = ead_df.to_crs(3857)
    
    print('This is the EAD for earthquakes: {:,}'.format(ead_df['ead'].sum()))
    print('This is the max EAD for road segment: {:,}'.format(ead_df['ead'].max()))
    for rp in haz_rp_lst:
        print('This is the overlay for RP {} for earthquakes: {:,}'.format(rp, ead_df['overlay_{}'.format(rp)].sum()))

    return ead_df

# %% [markdown]
# # Fluvial flooding

# %%
# Calculate and show risk calculations per curve
damage_data_path = damage_data_path / 'fluvial'
#curve_ead_df = risk_ead_per_curve(eq_damage_data_path)

# %%
haz_rp_lst = [5, 20, 50, 75, 100, 200, 250, 500, 1000]

# read parquets per return period
road_types_lst = ['unclassified', 'primary', 'secondary', 'tertiary', 'residential', 
                                'trunk', 'trunk_link',  'motorway','motorway_link',  'primary_link','secondary_link', 'tertiary_link','road', 'track' ]
road_types_lst_remove = []
assump_curves = ['F7.4', 'F7.5', 'F7.6', 'F7.7'] + ['F7.8', 'F7.9']
#create df with all unique ID numbers, geometry and column ead
ead_df = gpd.GeoDataFrame(columns=['osm_id', 'asset', 'geometry']+['ead_{}'.format(curve_id) for curve_id in assump_curves] 
                          +['ead_{}_overlay'.format(rp_trig) for rp_trig in haz_rp_lst], geometry='geometry')


for road_type in road_types_lst:
    #create damages_dictionary containing damages for different return periods for asset type
    damages_dict = {key: pd.DataFrame() for key in haz_rp_lst}
    for rp in haz_rp_lst:
        damage_data_path_list = damage_data_path.iterdir()
        data_path = [path for path in damage_data_path_list if '1in{}_road_{}'.format(rp,road_type) in str(path)]
        
        if len(data_path) != 0:
            df = gpd.read_parquet(data_path[0])
            damages_dict[rp] = pd.concat([damages_dict[rp], df], ignore_index=True)  #create dictionary with the return period 
            for curve_id in assump_curves: damages_dict[rp] = damages_dict[rp].rename(columns={curve_id: f"{curve_id}_{rp}"}) # Rename the curve_id column in the damages_dict[rp] DataFrame
        else:
            print('No data for {}'.format(road_type))
            road_types_lst_remove.append(road_type)

    if road_type not in road_types_lst_remove:
        #calculate EAD
        osm_id_columns = [df['osm_id'] for df in damages_dict.values()] # Get all 'osm_id' columns from the DataFrames in damages_dict
        if all(df.equals(osm_id_columns[0]) for df in osm_id_columns): # Compare all 'osm_id' columns
            print("All osm_id columns are equal: True")
            temp_df = damages_dict[haz_rp_lst[0]][['osm_id', 'asset', 'geometry']]
            #temp_df = temp_df[0:2]
            print('These are the damages per return period for {}'.format(road_type))
            for curve_id in assump_curves:
                temp_df_curve = temp_df[['osm_id']]
                for rp in haz_rp_lst: #print(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]])
                    temp_df_curve = temp_df_curve.merge(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]], on='osm_id', how='left')
                temp_df_curve.set_index('osm_id', inplace=True)
                temp_df_curve.columns = temp_df_curve.columns.str.replace(f"{curve_id}_", '', regex=False)
                temp_df.loc[:, ['ead_{}'.format(curve_id)]] = temp_df.apply(lambda row: calculate_risk_vectorized(temp_df_curve.loc[row['osm_id']]) if row['osm_id'] in temp_df_curve.index else np.nan, axis=1)
                for rp in haz_rp_lst: print("The damage for a {} year return event following curve {}: {:,.2f}".format(rp, curve_id, temp_df_curve['{}'.format(rp)].sum()))
            ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period 
        
        else:
            temp_df = pd.concat([damages_dict[rp][['osm_id', 'asset', 'geometry']] for rp in damages_dict.keys()]).drop_duplicates(subset=['osm_id']) #merge dataframes into one and remove duplicates based on id_number 
            print("osm_id columns are not equal")

ead_df = ead_df.to_crs(3857)

for curve_id in assump_curves:
    print('This is the EAD for earthquakes using curve {}: {:,}'.format(curve_id, ead_df['ead_{}'.format(curve_id)].sum()))
    #print('This is the max EAD for road segment using curve {}: {:,}'.format(curve_id, ead_df['ead_{}'.format(curve_id)].max()))
# Out:
# All osm_id columns are equal: True
# These are the damages per return period for unclassified
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 39
#      37 temp_df_curve = temp_df[['osm_id']]
#      38 for rp in haz_rp_lst: #print(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]])
# ---> 39     temp_df_curve = temp_df_curve.merge(damages_dict[rp][['osm_id', f"{curve_id}_{rp}"]], on='osm_id', how='left')
#      40 temp_df_curve.set_index('osm_id', inplace=True)
#      41 temp_df_curve.columns = temp_df_curve.columns.str.replace(f"{curve_id}_", '', regex=False)
#
# File ~\AppData\Local\miniforge3\envs\py311\Lib\site-packages\geopandas\geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
#    1464         and key == ""
#    (...)
#    1467         and not is_geometry_type(result)
#    1468     ):
#
# File ~\AppData\Local\miniforge3\envs\py311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniforge3\envs\py311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniforge3\envs\py311\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['F7.4_5'] not in index"

# %%
# Calculate and show risk calculations based on road conditions
eq_damage_data_path = damage_data_path / 'earthquake_giri'
ead_df = risk_ead_combined(eq_damage_data_path)
# Out:
# All osm_id columns are equal: True
# These are the damages per return period for unclassified
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 10,332,636.29
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 30,232,029.12
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 111,665,403.17
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 179,257,182.69
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 280,726,566.88
# This is overlay dict for 250 and unclassified
# This is overlay dict for 475 and unclassified
# This is overlay dict for 975 and unclassified
# This is overlay dict for 1500 and unclassified
# This is overlay dict for 2475 and unclassified
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:171: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# All osm_id columns are equal: True
# These are the damages per return period for primary
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 9,799,206.47
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 38,625,131.52
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 100,863,517.81
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 184,740,222.69
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 305,769,219.35
# This is overlay dict for 250 and primary
# This is overlay dict for 475 and primary
# This is overlay dict for 975 and primary
# This is overlay dict for 1500 and primary
# This is overlay dict for 2475 and primary
# All osm_id columns are equal: True
# These are the damages per return period for secondary
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 20,600,897.57
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 56,290,204.86
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 181,862,995.37
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 289,436,551.64
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 443,939,756.99
# This is overlay dict for 250 and secondary
# This is overlay dict for 475 and secondary
# This is overlay dict for 975 and secondary
# This is overlay dict for 1500 and secondary
# This is overlay dict for 2475 and secondary
# All osm_id columns are equal: True
# These are the damages per return period for tertiary
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 25,865,508.20
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 68,272,947.88
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 240,120,498.22
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 384,718,016.26
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 591,322,356.71
# This is overlay dict for 250 and tertiary
# This is overlay dict for 475 and tertiary
# This is overlay dict for 975 and tertiary
# This is overlay dict for 1500 and tertiary
# This is overlay dict for 2475 and tertiary
# All osm_id columns are equal: True
# These are the damages per return period for residential
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 53,883,539.82
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 167,294,484.86
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 575,546,599.65
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 949,636,921.08
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,531,465,278.88
# This is overlay dict for 250 and residential
# This is overlay dict for 475 and residential
# This is overlay dict for 975 and residential
# This is overlay dict for 1500 and residential
# This is overlay dict for 2475 and residential
# All osm_id columns are equal: True
# These are the damages per return period for trunk
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 9,530,406.67
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 17,829,749.52
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 58,185,035.15
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 95,464,741.32
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 206,916,678.32
# This is overlay dict for 250 and trunk
# This is overlay dict for 475 and trunk
# This is overlay dict for 975 and trunk
# This is overlay dict for 1500 and trunk
# This is overlay dict for 2475 and trunk
# All osm_id columns are equal: True
# These are the damages per return period for trunk_link
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 242,161.68
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 406,880.88
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,212,232.96
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,567,320.06
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 5,012,030.70
# This is overlay dict for 250 and trunk_link
# This is overlay dict for 475 and trunk_link
# This is overlay dict for 975 and trunk_link
# This is overlay dict for 1500 and trunk_link
# This is overlay dict for 2475 and trunk_link
# All osm_id columns are equal: True
# These are the damages per return period for motorway
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 18,348,623.10
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 39,137,065.81
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 84,211,239.40
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 147,772,938.86
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 184,048,034.91
# This is overlay dict for 250 and motorway
# This is overlay dict for 475 and motorway
# This is overlay dict for 975 and motorway
# This is overlay dict for 1500 and motorway
# This is overlay dict for 2475 and motorway
# All osm_id columns are equal: True
# These are the damages per return period for motorway_link
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 3,838,354.07
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 6,969,175.87
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 13,106,585.43
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 23,072,621.59
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 30,710,880.13
# This is overlay dict for 250 and motorway_link
# This is overlay dict for 475 and motorway_link
# This is overlay dict for 975 and motorway_link
# This is overlay dict for 1500 and motorway_link
# This is overlay dict for 2475 and motorway_link
# All osm_id columns are equal: True
# These are the damages per return period for primary_link
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 194,916.87
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 375,131.23
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 611,456.21
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,235,321.24
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 5,882,848.80
# This is overlay dict for 250 and primary_link
# This is overlay dict for 475 and primary_link
# This is overlay dict for 975 and primary_link
# This is overlay dict for 1500 and primary_link
# This is overlay dict for 2475 and primary_link
# All osm_id columns are equal: True
# These are the damages per return period for secondary_link
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 47,617.59
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 113,548.27
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 242,132.17
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 636,472.89
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,740,147.69
# This is overlay dict for 250 and secondary_link
# This is overlay dict for 475 and secondary_link
# This is overlay dict for 975 and secondary_link
# This is overlay dict for 1500 and secondary_link
# This is overlay dict for 2475 and secondary_link
# All osm_id columns are equal: True
# These are the damages per return period for tertiary_link
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 6,843.76
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 30,465.83
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 208,583.94
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 454,501.06
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 758,032.40
# This is overlay dict for 250 and tertiary_link
# This is overlay dict for 475 and tertiary_link
# This is overlay dict for 975 and tertiary_link
# This is overlay dict for 1500 and tertiary_link
# This is overlay dict for 2475 and tertiary_link
# All osm_id columns are equal: True
# These are the damages per return period for road
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 7,760.60
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 14,742.13
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 24,477.90
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 106,843.68
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,597,561.41
# This is overlay dict for 250 and road
# This is overlay dict for 475 and road
# This is overlay dict for 975 and road
# This is overlay dict for 1500 and road
# This is overlay dict for 2475 and road
# All osm_id columns are equal: True
# These are the damages per return period for track
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 46,718,805.03
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 112,650,398.75
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 408,472,481.70
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 637,684,527.33
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 988,315,683.13
# This is overlay dict for 250 and track
# This is overlay dict for 475 and track
# This is overlay dict for 975 and track
# This is overlay dict for 1500 and track
# This is overlay dict for 2475 and track
# This is the EAD for earthquakes: 104,927,870.14578722
# This is the max EAD for road segment: 719,341.2503112697
# This is the overlay for RP 250 for earthquakes: 6,277,249.783451214
# This is the overlay for RP 475 for earthquakes: 10,219,221.787450796
# This is the overlay for RP 975 for earthquakes: 21,796,842.331265736
# This is the overlay for RP 1500 for earthquakes: 28,196,721.38726194
# This is the overlay for RP 2475 for earthquakes: 37,602,393.74223512

# %%
ead_df
# Out:
#             osm_id         asset  \
# 0         20627582  unclassified
# 1         20647355  unclassified
# 2         20858453  unclassified
# 3         20861467  unclassified
# 4         24354040  unclassified
# ...            ...           ...
# 175208  1298785347         track
# 175209  1298785348         track
# 175210  1298785350         track
# 175211  1298785351         track
# 175212  1298785353         track
#
#                                                  geometry         ead  \
# 0       LINESTRING (5002657.051 5104107.600, 5002518.9...  222.517967
# 1       LINESTRING (5010846.147 5130468.599, 5010771.9...    0.000000
# 2       LINESTRING (4981041.121 5146559.699, 4980827.1...  148.224993
# 3       LINESTRING (5010746.917 5104084.727, 5010295.5...   43.886273
# 4       LINESTRING (5004093.484 5114141.022, 5004095.6...    0.000000
# ...                                                   ...         ...
# 175208  LINESTRING (4884324.210 5164619.757, 4884286.6...   92.669270
# 175209  LINESTRING (4884267.392 5164285.652, 4884320.1...   26.557874
# 175210  LINESTRING (4884400.274 5164033.133, 4884397.1...    0.000000
# 175211  LINESTRING (4884093.878 5163895.653, 4884080.3...    0.000000
# 175212  LINESTRING (4888324.242 5166538.165, 4888319.7...  350.608439
#
#         overlay_250  overlay_475  overlay_975  overlay_1500  overlay_2475
# 0               NaN  1246.800853  1246.800853   1246.800853   2551.600927
# 1               NaN          NaN          NaN           NaN           NaN
# 2               NaN          NaN          NaN   2463.280091   2463.280091
# 3               NaN          NaN          NaN           NaN   1202.759300
# 4               NaN          NaN          NaN           NaN           NaN
# ...             ...          ...          ...           ...           ...
# 175208          NaN          NaN   774.761983    774.761983    774.761983
# 175209          NaN          NaN   222.037264    222.037264    222.037264
# 175210          NaN          NaN          NaN           NaN           NaN
# 175211          NaN          NaN          NaN           NaN           NaN
# 175212          NaN          NaN  2898.059434   2898.059434   2898.059434
#
# [175213 rows x 9 columns]

# %%
subnational_df = gpd.read_file(admin_path / 'gadm41_{}.gpkg'.format(country),layer=2)
subnational_df = subnational_df.to_crs(3857)
ead_df['GID_2'] = ead_df.apply(lambda road_segment: get_province(road_segment, subnational_df), axis=1)
subnational_df = subnational_df.merge(ead_df[['GID_2','ead']].groupby('GID_2').sum(),left_on='GID_2',right_index=True)
subnational_df[['NAME_2','ead']].groupby('NAME_2').sum().sort_values(by='ead',ascending=False)

# %%
subnational_df['binned'] =  pd.cut(subnational_df.ead,[0,1e4,5e4,1e6,2e6,subnational_df.ead.max()],labels=['\\$1-$100,000','\\$100,000-$500,000',
                                                                                                       '\\$500,000-$1 million','\\$1 million-$2 million','> $2 million'])

fig, ax = plt.subplots(1,1,figsize=(10, 10))

subnational_df.plot(column = 'binned',cmap='copper_r',legend=True,ax=ax)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron,alpha=0.5)
subnational_df.dissolve('GID_0').plot(ax=ax,facecolor="none",edgecolor='black')
ax.set_axis_off()

#plt.savefig(figures_path /'eq_EAD_municipal.png', bbox_inches='tight', dpi=300)

# %%
ead_df['damage/km'] = ead_df.ead/(ead_df.overlay_2475/1000)

# %%
ead_df['damage/km'].max()

# %%
# figure EAD damages per km per road segment
ead_df['damage/km_binned'] = pd.cut(ead_df['damage/km'],[0,1e3,1e4,2.5e4,ead_df['damage/km'].max()],labels=['\\$1-$1,000','\\$1,000-$10,000','\\$10,000-$25,000','> $25,000'])
ead_df = gpd.GeoDataFrame(ead_df, geometry='geometry') # Set the GeoDataFrame's geometry column
ead_df = ead_df.to_crs(3857)

fig, ax = plt.subplots(1,1,figsize=(10, 10))
subnational.dissolve('GID_0').plot(ax=ax,facecolor="none",edgecolor='black')

ead_df.plot(column ='damage/km_binned',cmap='copper_r',legend=True,ax=ax)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron,alpha=0.5)
ax.set_axis_off()

plt.savefig(figures_path /'eq_EAD_km.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# # Earthquake figures based on GEM data

# %%
# Calculate and show risk calculations per curve
eq_damage_data_path = damage_data_path / 'earthquake_gem'
curve_ead_df = risk_ead_per_curve(eq_damage_data_path)
# Out:
# All osm_id columns are equal: True
# These are the damages per return period for unclassified
# The damage for a 475 year return event following curve E7.1: 21,408,522.60
# The damage for a 2475 year return event following curve E7.1: 339,864,500.38
# The damage for a 475 year return event following curve E7.6: 20,338,821.54
# The damage for a 2475 year return event following curve E7.6: 288,030,914.70
# The damage for a 475 year return event following curve E7.7: 21,088,244.68
# The damage for a 2475 year return event following curve E7.7: 309,046,977.13
# The damage for a 475 year return event following curve E7.8: 16,502,830.38
# The damage for a 2475 year return event following curve E7.8: 280,528,104.53
# The damage for a 475 year return event following curve E7.9: 38,487,151.14
# The damage for a 2475 year return event following curve E7.9: 511,875,536.78
# The damage for a 475 year return event following curve E7.10: 45,317,109.96
# The damage for a 2475 year return event following curve E7.10: 636,998,868.44
# The damage for a 475 year return event following curve E7.11: 88,084,138.99
# The damage for a 2475 year return event following curve E7.11: 963,341,879.97
# The damage for a 475 year return event following curve E7.12: 17,220,147.03
# The damage for a 2475 year return event following curve E7.12: 245,360,440.43
# The damage for a 475 year return event following curve E7.13: 21,628,101.43
# The damage for a 2475 year return event following curve E7.13: 291,389,117.43
# The damage for a 475 year return event following curve E7.14: 28,192,163.15
# The damage for a 2475 year return event following curve E7.14: 365,078,722.44
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\120827634.py:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period
# All osm_id columns are equal: True
# These are the damages per return period for primary
# The damage for a 475 year return event following curve E7.1: 8,229,615.12
# The damage for a 2475 year return event following curve E7.1: 290,165,220.51
# The damage for a 475 year return event following curve E7.6: 8,321,612.17
# The damage for a 2475 year return event following curve E7.6: 248,285,530.17
# The damage for a 475 year return event following curve E7.7: 8,478,370.89
# The damage for a 2475 year return event following curve E7.7: 265,591,850.51
# The damage for a 475 year return event following curve E7.8: 6,164,122.79
# The damage for a 2475 year return event following curve E7.8: 236,710,435.17
# The damage for a 475 year return event following curve E7.9: 16,075,234.44
# The damage for a 2475 year return event following curve E7.9: 446,527,586.02
# The damage for a 475 year return event following curve E7.10: 18,277,476.01
# The damage for a 2475 year return event following curve E7.10: 555,278,604.71
# The damage for a 475 year return event following curve E7.11: 39,811,037.90
# The damage for a 2475 year return event following curve E7.11: 858,881,702.68
# The damage for a 475 year return event following curve E7.12: 7,044,103.86
# The damage for a 2475 year return event following curve E7.12: 211,020,952.92
# The damage for a 475 year return event following curve E7.13: 9,072,485.35
# The damage for a 2475 year return event following curve E7.13: 252,236,415.30
# The damage for a 475 year return event following curve E7.14: 12,010,409.36
# The damage for a 2475 year return event following curve E7.14: 317,778,526.03
# All osm_id columns are equal: True
# These are the damages per return period for secondary
# The damage for a 475 year return event following curve E7.1: 48,550,445.74
# The damage for a 2475 year return event following curve E7.1: 514,115,388.13
# The damage for a 475 year return event following curve E7.6: 45,970,881.82
# The damage for a 2475 year return event following curve E7.6: 429,922,378.78
# The damage for a 475 year return event following curve E7.7: 47,715,169.65
# The damage for a 2475 year return event following curve E7.7: 463,218,492.07
# The damage for a 475 year return event following curve E7.8: 37,412,373.16
# The damage for a 2475 year return event following curve E7.8: 429,481,873.57
# The damage for a 475 year return event following curve E7.9: 87,014,667.16
# The damage for a 2475 year return event following curve E7.9: 754,286,181.35
# The damage for a 475 year return event following curve E7.10: 102,791,139.79
# The damage for a 2475 year return event following curve E7.10: 942,066,302.65
# The damage for a 475 year return event following curve E7.11: 198,005,641.02
# The damage for a 2475 year return event following curve E7.11: 1,377,760,392.64
# The damage for a 475 year return event following curve E7.12: 38,904,939.77
# The damage for a 2475 year return event following curve E7.12: 366,990,918.58
# The damage for a 475 year return event following curve E7.13: 48,786,920.84
# The damage for a 2475 year return event following curve E7.13: 432,425,936.98
# The damage for a 475 year return event following curve E7.14: 63,543,637.30
# The damage for a 2475 year return event following curve E7.14: 538,284,118.02
# All osm_id columns are equal: True
# These are the damages per return period for tertiary
# The damage for a 475 year return event following curve E7.1: 45,605,776.48
# The damage for a 2475 year return event following curve E7.1: 613,721,874.32
# The damage for a 475 year return event following curve E7.6: 43,976,386.00
# The damage for a 2475 year return event following curve E7.6: 519,102,310.47
# The damage for a 475 year return event following curve E7.7: 45,403,318.91
# The damage for a 2475 year return event following curve E7.7: 557,320,156.80
# The damage for a 475 year return event following curve E7.8: 34,949,227.00
# The damage for a 2475 year return event following curve E7.8: 507,600,805.61
# The damage for a 475 year return event following curve E7.9: 83,599,645.37
# The damage for a 2475 year return event following curve E7.9: 920,587,368.73
# The damage for a 475 year return event following curve E7.10: 97,546,523.83
# The damage for a 2475 year return event following curve E7.10: 1,146,022,913.23
# The damage for a 475 year return event following curve E7.11: 195,250,174.46
# The damage for a 2475 year return event following curve E7.11: 1,725,005,511.87
# The damage for a 475 year return event following curve E7.12: 37,236,624.06
# The damage for a 2475 year return event following curve E7.12: 442,362,606.87
# The damage for a 475 year return event following curve E7.13: 47,055,972.96
# The damage for a 2475 year return event following curve E7.13: 524,715,035.60
# The damage for a 475 year return event following curve E7.14: 61,568,855.17
# The damage for a 2475 year return event following curve E7.14: 656,745,654.02
# All osm_id columns are equal: True
# These are the damages per return period for residential
# The damage for a 475 year return event following curve E7.1: 116,724,144.83
# The damage for a 2475 year return event following curve E7.1: 1,457,998,371.23
# The damage for a 475 year return event following curve E7.6: 110,653,181.23
# The damage for a 2475 year return event following curve E7.6: 1,228,630,701.85
# The damage for a 475 year return event following curve E7.7: 114,806,750.20
# The damage for a 2475 year return event following curve E7.7: 1,320,638,770.74
# The damage for a 475 year return event following curve E7.8: 90,056,577.07
# The damage for a 2475 year return event following curve E7.8: 1,210,241,220.83
# The damage for a 475 year return event following curve E7.9: 209,265,053.98
# The damage for a 2475 year return event following curve E7.9: 2,170,466,741.01
# The damage for a 475 year return event following curve E7.10: 246,725,293.11
# The damage for a 2475 year return event following curve E7.10: 2,704,421,183.90
# The damage for a 475 year return event following curve E7.11: 477,318,941.26
# The damage for a 2475 year return event following curve E7.11: 4,032,200,845.65
# The damage for a 475 year return event following curve E7.12: 93,681,326.86
# The damage for a 2475 year return event following curve E7.12: 1,047,692,616.61
# The damage for a 475 year return event following curve E7.13: 117,537,634.17
# The damage for a 2475 year return event following curve E7.13: 1,239,825,171.24
# The damage for a 475 year return event following curve E7.14: 153,112,211.10
# The damage for a 2475 year return event following curve E7.14: 1,548,778,107.77
# All osm_id columns are equal: True
# These are the damages per return period for trunk
# The damage for a 475 year return event following curve E7.1: 15,264,591.56
# The damage for a 2475 year return event following curve E7.1: 256,309,067.01
# The damage for a 475 year return event following curve E7.6: 15,203,094.58
# The damage for a 2475 year return event following curve E7.6: 218,257,529.66
# The damage for a 475 year return event following curve E7.7: 15,551,397.39
# The damage for a 2475 year return event following curve E7.7: 233,825,459.29
# The damage for a 475 year return event following curve E7.8: 11,549,057.01
# The damage for a 2475 year return event following curve E7.8: 210,269,974.05
# The damage for a 475 year return event following curve E7.9: 29,162,614.80
# The damage for a 2475 year return event following curve E7.9: 390,321,105.31
# The damage for a 475 year return event following curve E7.10: 33,365,415.14
# The damage for a 2475 year return event following curve E7.10: 485,645,549.70
# The damage for a 475 year return event following curve E7.11: 71,084,632.25
# The damage for a 2475 year return event following curve E7.11: 742,879,738.91
# The damage for a 475 year return event following curve E7.12: 12,878,903.73
# The damage for a 2475 year return event following curve E7.12: 185,695,322.37
# The damage for a 475 year return event following curve E7.13: 16,495,979.33
# The damage for a 2475 year return event following curve E7.13: 221,272,657.80
# The damage for a 475 year return event following curve E7.14: 21,758,134.32
# The damage for a 2475 year return event following curve E7.14: 278,034,960.38
# All osm_id columns are equal: True
# These are the damages per return period for trunk_link
# The damage for a 475 year return event following curve E7.1: 209,611.17
# The damage for a 2475 year return event following curve E7.1: 5,894,340.26
# The damage for a 475 year return event following curve E7.6: 220,125.08
# The damage for a 2475 year return event following curve E7.6: 5,083,794.91
# The damage for a 475 year return event following curve E7.7: 221,836.50
# The damage for a 2475 year return event following curve E7.7: 5,425,062.92
# The damage for a 475 year return event following curve E7.8: 156,130.93
# The damage for a 2475 year return event following curve E7.8: 4,772,170.75
# The damage for a 475 year return event following curve E7.9: 426,435.38
# The damage for a 2475 year return event following curve E7.9: 9,209,317.11
# The damage for a 475 year return event following curve E7.10: 470,871.55
# The damage for a 2475 year return event following curve E7.10: 11,431,856.37
# The damage for a 475 year return event following curve E7.11: 1,108,845.50
# The damage for a 2475 year return event following curve E7.11: 17,986,694.56
# The damage for a 475 year return event following curve E7.12: 186,843.39
# The damage for a 2475 year return event following curve E7.12: 4,315,651.76
# The damage for a 475 year return event following curve E7.13: 244,334.90
# The damage for a 2475 year return event following curve E7.13: 5,180,868.03
# The damage for a 475 year return event following curve E7.14: 326,008.12
# The damage for a 2475 year return event following curve E7.14: 6,549,977.09
# All osm_id columns are equal: True
# These are the damages per return period for motorway
# The damage for a 475 year return event following curve E7.1: 44,926,600.72
# The damage for a 2475 year return event following curve E7.1: 205,845,575.97
# The damage for a 475 year return event following curve E7.6: 40,944,168.94
# The damage for a 2475 year return event following curve E7.6: 171,101,521.10
# The damage for a 475 year return event following curve E7.7: 42,970,430.73
# The damage for a 2475 year return event following curve E7.7: 184,778,251.27
# The damage for a 475 year return event following curve E7.8: 35,298,482.90
# The damage for a 2475 year return event following curve E7.8: 175,480,235.20
# The damage for a 475 year return event following curve E7.9: 76,273,946.37
# The damage for a 2475 year return event following curve E7.9: 293,569,376.23
# The damage for a 475 year return event following curve E7.10: 91,966,088.89
# The damage for a 2475 year return event following curve E7.10: 363,588,923.06
# The damage for a 475 year return event following curve E7.11: 164,172,722.05
# The damage for a 2475 year return event following curve E7.11: 522,803,496.02
# The damage for a 475 year return event following curve E7.12: 34,680,470.01
# The damage for a 2475 year return event following curve E7.12: 146,838,384.60
# The damage for a 475 year return event following curve E7.13: 42,774,331.79
# The damage for a 2475 year return event following curve E7.13: 171,513,586.93
# The damage for a 475 year return event following curve E7.14: 55,107,520.08
# The damage for a 2475 year return event following curve E7.14: 211,633,275.45
# All osm_id columns are equal: True
# These are the damages per return period for motorway_link
# The damage for a 475 year return event following curve E7.1: 6,664,297.59
# The damage for a 2475 year return event following curve E7.1: 32,926,452.93
# The damage for a 475 year return event following curve E7.6: 6,069,598.76
# The damage for a 2475 year return event following curve E7.6: 27,410,115.97
# The damage for a 475 year return event following curve E7.7: 6,371,331.66
# The damage for a 2475 year return event following curve E7.7: 29,586,395.86
# The damage for a 475 year return event following curve E7.8: 5,234,333.06
# The damage for a 2475 year return event following curve E7.8: 28,008,721.05
# The damage for a 475 year return event following curve E7.9: 11,309,785.61
# The damage for a 2475 year return event following curve E7.9: 47,147,991.37
# The damage for a 475 year return event following curve E7.10: 13,647,920.10
# The damage for a 2475 year return event following curve E7.10: 58,403,413.80
# The damage for a 475 year return event following curve E7.11: 24,312,320.15
# The damage for a 2475 year return event following curve E7.11: 84,335,350.54
# The damage for a 475 year return event following curve E7.12: 5,140,309.41
# The damage for a 2475 year return event following curve E7.12: 23,511,290.01
# The damage for a 475 year return event following curve E7.13: 6,338,094.76
# The damage for a 2475 year return event following curve E7.13: 27,495,732.48
# The damage for a 475 year return event following curve E7.14: 8,164,561.09
# The damage for a 2475 year return event following curve E7.14: 33,965,449.14
# All osm_id columns are equal: True
# These are the damages per return period for primary_link
# The damage for a 475 year return event following curve E7.1: 23,464.19
# The damage for a 2475 year return event following curve E7.1: 3,796,257.67
# The damage for a 475 year return event following curve E7.6: 21,979.88
# The damage for a 2475 year return event following curve E7.6: 3,188,380.01
# The damage for a 475 year return event following curve E7.7: 22,891.58
# The damage for a 2475 year return event following curve E7.7: 3,430,196.85
# The damage for a 475 year return event following curve E7.8: 18,023.90
# The damage for a 2475 year return event following curve E7.8: 3,141,804.52
# The damage for a 475 year return event following curve E7.9: 41,699.77
# The damage for a 2475 year return event following curve E7.9: 5,649,193.08
# The damage for a 475 year return event following curve E7.10: 49,846.93
# The damage for a 2475 year return event following curve E7.10: 7,072,337.20
# The damage for a 475 year return event following curve E7.11: 93,120.07
# The damage for a 2475 year return event following curve E7.11: 10,455,310.06
# The damage for a 475 year return event following curve E7.12: 18,567.49
# The damage for a 2475 year return event following curve E7.12: 2,715,626.26
# The damage for a 475 year return event following curve E7.13: 23,171.99
# The damage for a 2475 year return event following curve E7.13: 3,213,545.95
# The damage for a 475 year return event following curve E7.14: 30,114.94
# The damage for a 2475 year return event following curve E7.14: 4,016,490.72
# All osm_id columns are equal: True
# These are the damages per return period for secondary_link
# The damage for a 475 year return event following curve E7.1: 116,600.34
# The damage for a 2475 year return event following curve E7.1: 1,383,863.77
# The damage for a 475 year return event following curve E7.6: 108,652.45
# The damage for a 2475 year return event following curve E7.6: 1,154,721.07
# The damage for a 475 year return event following curve E7.7: 113,332.86
# The damage for a 2475 year return event following curve E7.7: 1,244,933.62
# The damage for a 475 year return event following curve E7.8: 89,796.13
# The damage for a 2475 year return event following curve E7.8: 1,155,327.98
# The damage for a 475 year return event following curve E7.9: 205,724.54
# The damage for a 2475 year return event following curve E7.9: 2,027,070.83
# The damage for a 475 year return event following curve E7.10: 246,637.32
# The damage for a 2475 year return event following curve E7.10: 2,537,562.65
# The damage for a 475 year return event following curve E7.11: 455,878.30
# The damage for a 2475 year return event following curve E7.11: 3,689,394.59
# The damage for a 475 year return event following curve E7.12: 91,789.61
# The damage for a 2475 year return event following curve E7.12: 985,304.16
# The damage for a 475 year return event following curve E7.13: 114,286.28
# The damage for a 2475 year return event following curve E7.13: 1,160,384.16
# The damage for a 475 year return event following curve E7.14: 148,307.88
# The damage for a 2475 year return event following curve E7.14: 1,444,193.33
# All osm_id columns are equal: True
# These are the damages per return period for tertiary_link
# The damage for a 475 year return event following curve E7.1: 83,407.15
# The damage for a 2475 year return event following curve E7.1: 624,631.28
# The damage for a 475 year return event following curve E7.6: 77,256.67
# The damage for a 2475 year return event following curve E7.6: 518,663.77
# The damage for a 475 year return event following curve E7.7: 80,720.80
# The damage for a 2475 year return event following curve E7.7: 560,093.81
# The damage for a 475 year return event following curve E7.8: 64,561.01
# The damage for a 2475 year return event following curve E7.8: 525,547.11
# The damage for a 475 year return event following curve E7.9: 145,698.99
# The damage for a 2475 year return event following curve E7.9: 902,772.60
# The damage for a 475 year return event following curve E7.10: 174,996.53
# The damage for a 2475 year return event following curve E7.10: 1,129,095.72
# The damage for a 475 year return event following curve E7.11: 320,259.49
# The damage for a 2475 year return event following curve E7.11: 1,620,326.11
# The damage for a 475 year return event following curve E7.12: 65,304.85
# The damage for a 2475 year return event following curve E7.12: 443,354.16
# The damage for a 475 year return event following curve E7.13: 81,094.88
# The damage for a 2475 year return event following curve E7.13: 520,013.96
# The damage for a 475 year return event following curve E7.14: 105,030.78
# The damage for a 2475 year return event following curve E7.14: 644,789.11
# All osm_id columns are equal: True
# These are the damages per return period for road
# The damage for a 475 year return event following curve E7.1: 86,970.49
# The damage for a 2475 year return event following curve E7.1: 1,741,178.14
# The damage for a 475 year return event following curve E7.6: 75,317.89
# The damage for a 2475 year return event following curve E7.6: 1,472,159.86
# The damage for a 475 year return event following curve E7.7: 80,268.28
# The damage for a 2475 year return event following curve E7.7: 1,580,738.69
# The damage for a 475 year return event following curve E7.8: 69,820.59
# The damage for a 2475 year return event following curve E7.8: 1,437,579.91
# The damage for a 475 year return event following curve E7.9: 137,484.67
# The damage for a 2475 year return event following curve E7.9: 2,614,305.29
# The damage for a 475 year return event following curve E7.10: 171,005.25
# The damage for a 2475 year return event following curve E7.10: 3,260,363.63
# The damage for a 475 year return event following curve E7.11: 270,956.65
# The damage for a 2475 year return event following curve E7.11: 4,893,884.40
# The damage for a 475 year return event following curve E7.12: 63,827.04
# The damage for a 2475 year return event following curve E7.12: 1,254,010.86
# The damage for a 475 year return event following curve E7.13: 76,875.68
# The damage for a 2475 year return event following curve E7.13: 1,487,406.60
# The damage for a 475 year return event following curve E7.14: 97,486.45
# The damage for a 2475 year return event following curve E7.14: 1,862,010.18
# All osm_id columns are equal: True
# These are the damages per return period for track
# The damage for a 475 year return event following curve E7.1: 112,040,633.13
# The damage for a 2475 year return event following curve E7.1: 1,274,419,541.48
# The damage for a 475 year return event following curve E7.6: 105,536,065.89
# The damage for a 2475 year return event following curve E7.6: 1,066,458,193.94
# The damage for a 475 year return event following curve E7.7: 109,707,182.30
# The damage for a 2475 year return event following curve E7.7: 1,148,813,989.64
# The damage for a 475 year return event following curve E7.8: 86,492,640.50
# The damage for a 2475 year return event following curve E7.8: 1,064,544,621.21
# The damage for a 475 year return event following curve E7.9: 199,474,453.63
# The damage for a 2475 year return event following curve E7.9: 1,871,315,932.35
# The damage for a 475 year return event following curve E7.10: 236,439,763.07
# The damage for a 2475 year return event following curve E7.10: 2,335,858,359.34
# The damage for a 475 year return event following curve E7.11: 450,490,749.22
# The damage for a 2475 year return event following curve E7.11: 3,422,679,395.91
# The damage for a 475 year return event following curve E7.12: 89,306,047.85
# The damage for a 2475 year return event following curve E7.12: 910,387,994.73
# The damage for a 475 year return event following curve E7.13: 111,741,331.68
# The damage for a 2475 year return event following curve E7.13: 1,072,994,393.50
# The damage for a 475 year return event following curve E7.14: 145,343,696.50
# The damage for a 2475 year return event following curve E7.14: 1,335,886,065.82
# This is the EAD for earthquakes using curve E7.1: 216,154,265.9459637
# This is the EAD for earthquakes using curve E7.6: 203,958,613.23569816
# This is the EAD for earthquakes using curve E7.7: 211,899,643.2587066
# This is the EAD for earthquakes using curve E7.8: 167,175,217.5974258
# This is the EAD for earthquakes using curve E7.9: 384,975,626.89310914
# This is the EAD for earthquakes using curve E7.10: 455,026,002.9186347
# This is the EAD for earthquakes using curve E7.11: 872,318,810.8931842
# This is the EAD for earthquakes using curve E7.12: 172,695,284.44267604
# This is the EAD for earthquakes using curve E7.13: 216,226,597.6460656
# This is the EAD for earthquakes using curve E7.14: 281,293,591.4817251

# %%
# Calculate and show risk calculations based on specific curve combinations
eq_damage_data_path = damage_data_path / 'earthquake_gem'
ead_df = risk_ead_combined(eq_damage_data_path)
# Out:
# All osm_id columns are equal: True
# These are the damages per return period for unclassified
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 64,957,406.14
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 735,149,824.70
# This is overlay dict for 475 and unclassified
# This is overlay dict for 2475 and unclassified
# All osm_id columns are equal: True
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:171: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# These are the damages per return period for primary
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 21,693,249.64
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 510,883,725.38
# This is overlay dict for 475 and primary
# This is overlay dict for 2475 and primary
# All osm_id columns are equal: True
# These are the damages per return period for secondary
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 135,505,524.77
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 993,175,456.06
# This is overlay dict for 475 and secondary
# This is overlay dict for 2475 and secondary
# All osm_id columns are equal: True
# These are the damages per return period for tertiary
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 143,567,241.04
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,317,646,311.66
# This is overlay dict for 475 and tertiary
# This is overlay dict for 2475 and tertiary
# All osm_id columns are equal: True
# These are the damages per return period for residential
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 352,163,508.20
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 3,085,704,586.31
# This is overlay dict for 475 and residential
# This is overlay dict for 2475 and residential
# All osm_id columns are equal: True
# These are the damages per return period for trunk
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 38,949,639.52
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 444,055,374.88
# This is overlay dict for 475 and trunk
# This is overlay dict for 2475 and trunk
# All osm_id columns are equal: True
# These are the damages per return period for trunk_link
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 596,951.61
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 10,626,870.52
# This is overlay dict for 475 and trunk_link
# This is overlay dict for 2475 and trunk_link
# All osm_id columns are equal: True
# These are the damages per return period for motorway
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 93,595,223.06
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 323,299,930.51
# This is overlay dict for 475 and motorway
# This is overlay dict for 2475 and motorway
# All osm_id columns are equal: True
# These are the damages per return period for motorway_link
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 13,864,372.70
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 52,034,927.32
# This is overlay dict for 475 and motorway_link
# This is overlay dict for 2475 and motorway_link
# All osm_id columns are equal: True
# These are the damages per return period for primary_link
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 52,311.50
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 6,322,372.82
# This is overlay dict for 475 and primary_link
# This is overlay dict for 2475 and primary_link
# All osm_id columns are equal: True
# These are the damages per return period for secondary_link
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 313,280.35
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 2,661,202.65
# This is overlay dict for 475 and secondary_link
# This is overlay dict for 2475 and secondary_link
# All osm_id columns are equal: True
# These are the damages per return period for tertiary_link
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 237,428.90
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,249,340.56
# This is overlay dict for 475 and tertiary_link
# This is overlay dict for 2475 and tertiary_link
# All osm_id columns are equal: True
# These are the damages per return period for road
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 204,642.89
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 3,738,009.35
# This is overlay dict for 475 and road
# This is overlay dict for 2475 and road
# All osm_id columns are equal: True
# These are the damages per return period for track
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 332,788,234.37
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 2,628,106,818.23
# This is overlay dict for 475 and track
# This is overlay dict for 2475 and track
# This is the EAD for earthquakes: 611,692,756.9384526
# This is the max EAD for road segment: 4,456,199.722013937
# This is the overlay for RP 475 for earthquakes: 12,536,012.750334034
# This is the overlay for RP 2475 for earthquakes: 64,238,121.62512896

# %%
ead_df
# Out:
#             osm_id         asset  \
# 0         20627582  unclassified
# 1         20647355  unclassified
# 2         20858453  unclassified
# 3         20861467  unclassified
# 4         24354040  unclassified
# ...            ...           ...
# 175208  1298785347         track
# 175209  1298785348         track
# 175210  1298785350         track
# 175211  1298785351         track
# 175212  1298785353         track
#
#                                                  geometry          ead  \
# 0       LINESTRING (5002657.051 5104107.600, 5002518.9...  4487.238443
# 1       LINESTRING (5010846.147 5130468.599, 5010771.9...     0.000000
# 2       LINESTRING (4981041.121 5146559.699, 4980827.1...  4506.205756
# 3       LINESTRING (5010746.917 5104084.727, 5010295.5...     0.000000
# 4       LINESTRING (5004093.484 5114141.022, 5004095.6...     0.000000
# ...                                                   ...          ...
# 175208  LINESTRING (4884324.210 5164619.757, 4884286.6...     0.000000
# 175209  LINESTRING (4884267.392 5164285.652, 4884320.1...     0.000000
# 175210  LINESTRING (4884400.274 5164033.133, 4884397.1...     0.000000
# 175211  LINESTRING (4884093.878 5163895.653, 4884080.3...     0.000000
# 175212  LINESTRING (4888324.242 5166538.165, 4888319.7...     0.000000
#
#         overlay_475  overlay_2475
# 0               NaN  42192.944572
# 1               NaN           NaN
# 2               NaN  25890.706604
# 3               NaN           NaN
# 4               NaN           NaN
# ...             ...           ...
# 175208          NaN           NaN
# 175209          NaN           NaN
# 175210          NaN           NaN
# 175211          NaN           NaN
# 175212          NaN           NaN
#
# [175213 rows x 6 columns]

# %% [markdown]
# # Earthquake figures based on GAR data

# %%
# Calculate and show risk calculations per curve
eq_damage_data_path = damage_data_path / 'earthquake_gar'
curve_ead_df = risk_ead_per_curve(eq_damage_data_path)
# Out:
# All osm_id columns are equal: True
# These are the damages per return period for unclassified
# The damage for a 250 year return event following curve E7.1: 104,652.71
# The damage for a 475 year return event following curve E7.1: 1,319,941.74
# The damage for a 975 year return event following curve E7.1: 33,948,922.13
# The damage for a 1500 year return event following curve E7.1: 73,142,856.21
# The damage for a 2475 year return event following curve E7.1: 131,833,716.10
# The damage for a 250 year return event following curve E7.6: 184,655.48
# The damage for a 475 year return event following curve E7.6: 1,690,665.06
# The damage for a 975 year return event following curve E7.6: 32,904,152.40
# The damage for a 1500 year return event following curve E7.6: 68,464,706.02
# The damage for a 2475 year return event following curve E7.6: 119,355,393.73
# The damage for a 250 year return event following curve E7.7: 163,171.01
# The damage for a 475 year return event following curve E7.7: 1,619,344.66
# The damage for a 975 year return event following curve E7.7: 33,939,086.95
# The damage for a 1500 year return event following curve E7.7: 71,325,571.31
# The damage for a 2475 year return event following curve E7.7: 125,545,005.33
# The damage for a 250 year return event following curve E7.8: 67,633.62
# The damage for a 475 year return event following curve E7.8: 914,439.93
# The damage for a 975 year return event following curve E7.8: 25,703,956.82
# The damage for a 1500 year return event following curve E7.8: 56,207,681.03
# The damage for a 2475 year return event following curve E7.8: 103,177,482.17
# The damage for a 250 year return event following curve E7.9: 365,667.32
# The damage for a 475 year return event following curve E7.9: 3,386,758.44
# The damage for a 975 year return event following curve E7.9: 63,121,620.11
# The damage for a 1500 year return event following curve E7.9: 129,870,562.90
# The damage for a 2475 year return event following curve E7.9: 223,023,921.93
# The damage for a 250 year return event following curve E7.10: 285,395.94
# The damage for a 475 year return event following curve E7.10: 3,318,109.34
# The damage for a 975 year return event following curve E7.10: 73,946,935.42
# The damage for a 1500 year return event following curve E7.10: 155,312,569.11
# The damage for a 2475 year return event following curve E7.10: 271,317,553.68
# The damage for a 250 year return event following curve E7.11: 1,458,752.93
# The damage for a 475 year return event following curve E7.11: 10,538,047.73
# The damage for a 975 year return event following curve E7.11: 147,606,074.66
# The damage for a 1500 year return event following curve E7.11: 289,494,352.16
# The damage for a 2475 year return event following curve E7.11: 473,319,647.25
# The damage for a 250 year return event following curve E7.12: 161,992.78
# The damage for a 475 year return event following curve E7.12: 1,443,770.79
# The damage for a 975 year return event following curve E7.12: 27,796,086.52
# The damage for a 1500 year return event following curve E7.12: 57,832,530.69
# The damage for a 2475 year return event following curve E7.12: 100,929,875.32
# The damage for a 250 year return event following curve E7.13: 249,165.93
# The damage for a 475 year return event following curve E7.13: 2,014,552.19
# The damage for a 975 year return event following curve E7.13: 35,174,096.91
# The damage for a 1500 year return event following curve E7.13: 72,129,914.76
# The damage for a 2475 year return event following curve E7.13: 124,066,745.63
# The damage for a 250 year return event following curve E7.14: 358,051.89
# The damage for a 475 year return event following curve E7.14: 2,780,659.81
# The damage for a 975 year return event following curve E7.14: 46,109,438.80
# The damage for a 1500 year return event following curve E7.14: 93,707,822.45
# The damage for a 2475 year return event following curve E7.14: 159,615,377.70
# No data for primary
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3087033421.py:97: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period
# All osm_id columns are equal: True
# These are the damages per return period for secondary
# The damage for a 250 year return event following curve E7.1: 134,473.84
# The damage for a 475 year return event following curve E7.1: 2,257,863.10
# The damage for a 975 year return event following curve E7.1: 54,884,969.85
# The damage for a 1500 year return event following curve E7.1: 116,957,891.98
# The damage for a 2475 year return event following curve E7.1: 207,866,617.57
# The damage for a 250 year return event following curve E7.6: 238,909.86
# The damage for a 475 year return event following curve E7.6: 2,864,219.15
# The damage for a 975 year return event following curve E7.6: 53,047,511.58
# The damage for a 1500 year return event following curve E7.6: 109,209,006.89
# The damage for a 2475 year return event following curve E7.6: 187,592,782.02
# The damage for a 250 year return event following curve E7.7: 210,748.44
# The damage for a 475 year return event following curve E7.7: 2,750,271.99
# The damage for a 975 year return event following curve E7.7: 54,761,137.67
# The damage for a 1500 year return event following curve E7.7: 113,853,162.98
# The damage for a 2475 year return event following curve E7.7: 197,504,544.66
# The damage for a 250 year return event following curve E7.8: 86,780.30
# The damage for a 475 year return event following curve E7.8: 1,567,542.89
# The damage for a 975 year return event following curve E7.8: 41,578,005.46
# The damage for a 1500 year return event following curve E7.8: 89,958,962.90
# The damage for a 2475 year return event following curve E7.8: 162,949,070.83
# The damage for a 250 year return event following curve E7.9: 472,779.67
# The damage for a 475 year return event following curve E7.9: 5,736,279.53
# The damage for a 975 year return event following curve E7.9: 101,724,906.09
# The damage for a 1500 year return event following curve E7.9: 207,005,477.63
# The damage for a 2475 year return event following curve E7.9: 350,027,624.69
# The damage for a 250 year return event following curve E7.10: 367,119.95
# The damage for a 475 year return event following curve E7.10: 5,658,060.49
# The damage for a 975 year return event following curve E7.10: 119,421,323.32
# The damage for a 1500 year return event following curve E7.10: 247,945,298.95
# The damage for a 2475 year return event following curve E7.10: 426,556,365.35
# The damage for a 250 year return event following curve E7.11: 1,895,400.16
# The damage for a 475 year return event following curve E7.11: 17,695,857.95
# The damage for a 975 year return event following curve E7.11: 236,916,524.24
# The damage for a 1500 year return event following curve E7.11: 459,793,138.15
# The damage for a 2475 year return event following curve E7.11: 739,171,846.23
# The damage for a 250 year return event following curve E7.12: 209,731.08
# The damage for a 475 year return event following curve E7.12: 2,444,239.96
# The damage for a 975 year return event following curve E7.12: 44,805,007.57
# The damage for a 1500 year return event following curve E7.12: 92,247,104.04
# The damage for a 2475 year return event following curve E7.12: 158,648,045.56
# The damage for a 250 year return event following curve E7.13: 323,244.42
# The damage for a 475 year return event following curve E7.13: 3,399,738.15
# The damage for a 975 year return event following curve E7.13: 56,630,180.10
# The damage for a 1500 year return event following curve E7.13: 114,933,996.16
# The damage for a 2475 year return event following curve E7.13: 194,741,892.74
# The damage for a 250 year return event following curve E7.14: 464,856.37
# The damage for a 475 year return event following curve E7.14: 4,685,864.97
# The damage for a 975 year return event following curve E7.14: 74,187,029.47
# The damage for a 1500 year return event following curve E7.14: 149,221,752.64
# The damage for a 2475 year return event following curve E7.14: 250,302,117.31
# All osm_id columns are equal: True
# These are the damages per return period for tertiary
# The damage for a 250 year return event following curve E7.1: 238,197.56
# The damage for a 475 year return event following curve E7.1: 2,368,359.69
# The damage for a 975 year return event following curve E7.1: 66,657,363.49
# The damage for a 1500 year return event following curve E7.1: 156,809,279.29
# The damage for a 2475 year return event following curve E7.1: 278,259,116.55
# The damage for a 250 year return event following curve E7.6: 424,406.03
# The damage for a 475 year return event following curve E7.6: 3,141,814.88
# The damage for a 975 year return event following curve E7.6: 65,136,482.90
# The damage for a 1500 year return event following curve E7.6: 147,431,934.05
# The damage for a 2475 year return event following curve E7.6: 252,324,161.09
# The damage for a 250 year return event following curve E7.7: 374,109.87
# The damage for a 475 year return event following curve E7.7: 2,982,999.83
# The damage for a 975 year return event following curve E7.7: 67,025,904.51
# The damage for a 1500 year return event following curve E7.7: 153,396,494.17
# The damage for a 2475 year return event following curve E7.7: 265,285,640.76
# The damage for a 250 year return event following curve E7.8: 153,622.96
# The damage for a 475 year return event following curve E7.8: 1,626,620.05
# The damage for a 975 year return event following curve E7.8: 50,370,531.07
# The damage for a 1500 year return event following curve E7.8: 120,302,606.21
# The damage for a 2475 year return event following curve E7.8: 217,616,425.11
# The damage for a 250 year return event following curve E7.9: 839,617.92
# The damage for a 475 year return event following curve E7.9: 6,303,175.62
# The damage for a 975 year return event following curve E7.9: 125,127,877.50
# The damage for a 1500 year return event following curve E7.9: 280,039,639.09
# The damage for a 2475 year return event following curve E7.9: 471,788,852.50
# The damage for a 250 year return event following curve E7.10: 650,587.99
# The damage for a 475 year return event following curve E7.10: 6,030,580.67
# The damage for a 975 year return event following curve E7.10: 145,727,483.59
# The damage for a 1500 year return event following curve E7.10: 333,966,514.43
# The damage for a 2475 year return event following curve E7.10: 573,420,257.03
# The damage for a 250 year return event following curve E7.11: 3,372,987.68
# The damage for a 475 year return event following curve E7.11: 20,186,163.71
# The damage for a 975 year return event following curve E7.11: 295,950,969.82
# The damage for a 1500 year return event following curve E7.11: 628,217,705.72
# The damage for a 2475 year return event following curve E7.11: 1,003,764,202.24
# The damage for a 250 year return event following curve E7.12: 372,677.42
# The damage for a 475 year return event following curve E7.12: 2,688,970.67
# The damage for a 975 year return event following curve E7.12: 55,045,917.02
# The damage for a 1500 year return event following curve E7.12: 124,541,694.46
# The damage for a 2475 year return event following curve E7.12: 213,366,175.02
# The damage for a 250 year return event following curve E7.13: 574,863.37
# The damage for a 475 year return event following curve E7.13: 3,792,665.22
# The damage for a 975 year return event following curve E7.13: 69,893,567.70
# The damage for a 1500 year return event following curve E7.13: 155,618,437.65
# The damage for a 2475 year return event following curve E7.13: 262,460,171.15
# The damage for a 250 year return event following curve E7.14: 826,969.12
# The damage for a 475 year return event following curve E7.14: 5,260,623.89
# The damage for a 975 year return event following curve E7.14: 91,797,888.04
# The damage for a 1500 year return event following curve E7.14: 202,403,581.48
# The damage for a 2475 year return event following curve E7.14: 337,818,096.03
# All osm_id columns are equal: True
# These are the damages per return period for residential
# The damage for a 250 year return event following curve E7.1: 211,372.42
# The damage for a 475 year return event following curve E7.1: 5,466,216.88
# The damage for a 975 year return event following curve E7.1: 125,579,942.91
# The damage for a 1500 year return event following curve E7.1: 307,753,229.85
# The damage for a 2475 year return event following curve E7.1: 608,234,441.30
# The damage for a 250 year return event following curve E7.6: 373,615.86
# The damage for a 475 year return event following curve E7.6: 6,955,785.72
# The damage for a 975 year return event following curve E7.6: 122,400,757.83
# The damage for a 1500 year return event following curve E7.6: 289,347,842.47
# The damage for a 2475 year return event following curve E7.6: 553,603,311.05
# The damage for a 250 year return event following curve E7.7: 329,999.51
# The damage for a 475 year return event following curve E7.7: 6,674,870.17
# The damage for a 975 year return event following curve E7.7: 126,053,500.80
# The damage for a 1500 year return event following curve E7.7: 301,063,370.57
# The damage for a 2475 year return event following curve E7.7: 581,416,648.44
# The damage for a 250 year return event following curve E7.8: 136,552.53
# The damage for a 475 year return event following curve E7.8: 3,789,583.54
# The damage for a 975 year return event following curve E7.8: 94,835,523.39
# The damage for a 1500 year return event following curve E7.8: 235,855,577.78
# The damage for a 2475 year return event following curve E7.8: 474,257,423.72
# The damage for a 250 year return event following curve E7.9: 739,728.53
# The damage for a 475 year return event following curve E7.9: 13,941,372.60
# The damage for a 975 year return event following curve E7.9: 235,250,698.09
# The damage for a 1500 year return event following curve E7.9: 550,026,375.95
# The damage for a 2475 year return event following curve E7.9: 1,037,664,560.05
# The damage for a 250 year return event following curve E7.10: 576,589.35
# The damage for a 475 year return event following curve E7.10: 13,729,232.37
# The damage for a 975 year return event following curve E7.10: 274,727,648.04
# The damage for a 1500 year return event following curve E7.10: 656,432,777.88
# The damage for a 2475 year return event following curve E7.10: 1,259,607,424.84
# The damage for a 250 year return event following curve E7.11: 2,954,748.34
# The damage for a 475 year return event following curve E7.11: 43,077,507.26
# The damage for a 975 year return event following curve E7.11: 554,019,693.57
# The damage for a 1500 year return event following curve E7.11: 1,233,372,264.09
# The damage for a 2475 year return event following curve E7.11: 2,219,967,505.11
# The damage for a 250 year return event following curve E7.12: 327,819.43
# The damage for a 475 year return event following curve E7.12: 5,935,624.18
# The damage for a 975 year return event following curve E7.12: 103,395,845.67
# The damage for a 1500 year return event following curve E7.12: 244,365,703.18
# The damage for a 2475 year return event following curve E7.12: 467,966,969.68
# The damage for a 250 year return event following curve E7.13: 504,490.49
# The damage for a 475 year return event following curve E7.13: 8,261,037.14
# The damage for a 975 year return event following curve E7.13: 131,129,799.14
# The damage for a 1500 year return event following curve E7.13: 305,339,556.42
# The damage for a 2475 year return event following curve E7.13: 576,631,974.28
# The damage for a 250 year return event following curve E7.14: 725,095.87
# The damage for a 475 year return event following curve E7.14: 11,390,044.87
# The damage for a 975 year return event following curve E7.14: 172,132,677.11
# The damage for a 1500 year return event following curve E7.14: 397,178,257.74
# The damage for a 2475 year return event following curve E7.14: 743,136,678.67
# All osm_id columns are equal: True
# These are the damages per return period for trunk
# The damage for a 250 year return event following curve E7.1: 229,656.27
# The damage for a 475 year return event following curve E7.1: 1,124,730.76
# The damage for a 975 year return event following curve E7.1: 8,786,585.62
# The damage for a 1500 year return event following curve E7.1: 28,709,877.80
# The damage for a 2475 year return event following curve E7.1: 86,509,618.51
# The damage for a 250 year return event following curve E7.6: 404,428.31
# The damage for a 475 year return event following curve E7.6: 1,574,992.39
# The damage for a 975 year return event following curve E7.6: 9,015,401.31
# The damage for a 1500 year return event following curve E7.6: 27,611,918.94
# The damage for a 2475 year return event following curve E7.6: 80,159,570.53
# The damage for a 250 year return event following curve E7.7: 357,549.70
# The damage for a 475 year return event following curve E7.7: 1,475,378.11
# The damage for a 975 year return event following curve E7.7: 9,149,426.91
# The damage for a 1500 year return event following curve E7.7: 28,543,987.52
# The damage for a 2475 year return event following curve E7.7: 83,754,929.86
# The damage for a 250 year return event following curve E7.8: 148,480.11
# The damage for a 475 year return event following curve E7.8: 762,947.12
# The damage for a 975 year return event following curve E7.8: 6,555,579.00
# The damage for a 1500 year return event following curve E7.8: 21,827,591.03
# The damage for a 2475 year return event following curve E7.8: 66,807,592.17
# The damage for a 250 year return event following curve E7.9: 801,033.94
# The damage for a 475 year return event following curve E7.9: 3,162,258.51
# The damage for a 975 year return event following curve E7.9: 17,466,705.68
# The damage for a 1500 year return event following curve E7.9: 52,817,334.70
# The damage for a 2475 year return event following curve E7.9: 151,457,699.21
# The damage for a 250 year return event following curve E7.10: 626,097.08
# The damage for a 475 year return event following curve E7.10: 2,914,740.33
# The damage for a 975 year return event following curve E7.10: 19,662,826.04
# The damage for a 1500 year return event following curve E7.10: 62,124,450.11
# The damage for a 2475 year return event following curve E7.10: 182,157,866.44
# The damage for a 250 year return event following curve E7.11: 3,191,039.47
# The damage for a 475 year return event following curve E7.11: 10,574,835.94
# The damage for a 975 year return event following curve E7.11: 43,975,982.48
# The damage for a 1500 year return event following curve E7.11: 122,227,826.94
# The damage for a 2475 year return event following curve E7.11: 332,651,145.65
# The damage for a 250 year return event following curve E7.12: 354,724.07
# The damage for a 475 year return event following curve E7.12: 1,353,130.69
# The damage for a 975 year return event following curve E7.12: 7,634,614.25
# The damage for a 1500 year return event following curve E7.12: 23,327,789.99
# The damage for a 2475 year return event following curve E7.12: 67,721,473.05
# The damage for a 250 year return event following curve E7.13: 545,297.13
# The damage for a 475 year return event following curve E7.13: 1,940,098.54
# The damage for a 975 year return event following curve E7.13: 9,882,943.76
# The damage for a 1500 year return event following curve E7.13: 29,420,516.84
# The damage for a 2475 year return event following curve E7.13: 84,091,163.81
# The damage for a 250 year return event following curve E7.14: 783,422.04
# The damage for a 475 year return event following curve E7.14: 2,710,416.54
# The damage for a 975 year return event following curve E7.14: 13,120,392.44
# The damage for a 1500 year return event following curve E7.14: 38,485,268.58
# The damage for a 2475 year return event following curve E7.14: 108,935,149.78
# No data for trunk_link
# No data for trunk_link
# No data for motorway
# No data for motorway_link
# No data for primary_link
# No data for primary_link
# No data for secondary_link
# No data for secondary_link
# No data for tertiary_link
# No data for road
# No data for road
# All osm_id columns are equal: True
# These are the damages per return period for track
# The damage for a 250 year return event following curve E7.1: 453,969.01
# The damage for a 475 year return event following curve E7.1: 3,742,306.56
# The damage for a 975 year return event following curve E7.1: 102,521,239.07
# The damage for a 1500 year return event following curve E7.1: 250,319,842.88
# The damage for a 2475 year return event following curve E7.1: 453,426,259.37
# The damage for a 250 year return event following curve E7.6: 806,814.56
# The damage for a 475 year return event following curve E7.6: 4,872,904.61
# The damage for a 975 year return event following curve E7.6: 100,626,859.61
# The damage for a 1500 year return event following curve E7.6: 235,995,921.78
# The damage for a 2475 year return event following curve E7.6: 412,404,825.68
# The damage for a 250 year return event following curve E7.7: 711,649.40
# The damage for a 475 year return event following curve E7.7: 4,647,130.24
# The damage for a 975 year return event following curve E7.7: 103,421,275.85
# The damage for a 1500 year return event following curve E7.7: 245,355,260.13
# The damage for a 2475 year return event following curve E7.7: 433,210,963.70
# The damage for a 250 year return event following curve E7.8: 292,939.22
# The damage for a 475 year return event following curve E7.8: 2,584,356.22
# The damage for a 975 year return event following curve E7.8: 77,267,164.54
# The damage for a 1500 year return event following curve E7.8: 191,670,151.01
# The damage for a 2475 year return event following curve E7.8: 353,815,130.11
# The damage for a 250 year return event following curve E7.9: 1,596,553.01
# The damage for a 475 year return event following curve E7.9: 9,761,065.47
# The damage for a 975 year return event following curve E7.9: 193,670,600.10
# The damage for a 1500 year return event following curve E7.9: 448,926,021.41
# The damage for a 2475 year return event following curve E7.9: 772,536,125.94
# The damage for a 250 year return event following curve E7.10: 1,239,425.52
# The damage for a 475 year return event following curve E7.10: 9,450,863.68
# The damage for a 975 year return event following curve E7.10: 225,090,195.54
# The damage for a 1500 year return event following curve E7.10: 534,793,795.71
# The damage for a 2475 year return event following curve E7.10: 937,875,990.67
# The damage for a 250 year return event following curve E7.11: 6,402,265.02
# The damage for a 475 year return event following curve E7.11: 30,831,425.64
# The damage for a 975 year return event following curve E7.11: 460,439,465.39
# The damage for a 1500 year return event following curve E7.11: 1,010,704,844.10
# The damage for a 2475 year return event following curve E7.11: 1,651,135,761.12
# The damage for a 250 year return event following curve E7.12: 708,300.19
# The damage for a 475 year return event following curve E7.12: 4,166,871.37
# The damage for a 975 year return event following curve E7.12: 85,025,146.16
# The damage for a 1500 year return event following curve E7.12: 199,320,597.85
# The damage for a 2475 year return event following curve E7.12: 348,647,646.60
# The damage for a 250 year return event following curve E7.13: 1,091,766.39
# The damage for a 475 year return event following curve E7.13: 5,846,632.22
# The damage for a 975 year return event following curve E7.13: 108,142,369.51
# The damage for a 1500 year return event following curve E7.13: 249,344,219.86
# The damage for a 2475 year return event following curve E7.13: 429,466,757.02
# The damage for a 250 year return event following curve E7.14: 1,570,124.55
# The damage for a 475 year return event following curve E7.14: 8,089,980.53
# The damage for a 975 year return event following curve E7.14: 142,190,798.02
# The damage for a 1500 year return event following curve E7.14: 324,567,640.79
# The damage for a 2475 year return event following curve E7.14: 553,333,809.68
# This is the EAD for earthquakes using curve E7.1: 2,226,860.0191612733
# This is the EAD for earthquakes using curve E7.6: 2,653,199.3795622895
# This is the EAD for earthquakes using curve E7.7: 2,571,893.8635449493
# This is the EAD for earthquakes using curve E7.8: 1,632,460.1030041133
# This is the EAD for earthquakes using curve E7.9: 5,123,347.13476324
# This is the EAD for earthquakes using curve E7.10: 5,120,575.824247523
# This is the EAD for earthquakes using curve E7.11: 15,666,304.783851128
# This is the EAD for earthquakes using curve E7.12: 2,282,156.4336119224
# This is the EAD for earthquakes using curve E7.13: 3,156,902.792252351
# This is the EAD for earthquakes using curve E7.14: 4,326,681.473105015

# %%
# Calculate and show risk calculations based on specific curve combinations
eq_damage_data_path = damage_data_path / 'earthquake_gar'
ead_df = risk_ead_combined(eq_damage_data_path)
# Out:
# All osm_id columns are equal: True
# These are the damages per return period for unclassified
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,018,149.04
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 7,489,887.03
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 108,406,428.80
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 214,102,593.02
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 352,860,907.29
# This is overlay dict for 250 and unclassified
# This is overlay dict for 475 and unclassified
# This is overlay dict for 975 and unclassified
# This is overlay dict for 1500 and unclassified
# This is overlay dict for 2475 and unclassified
# No data for primary
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:171: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ead_df = pd.concat([ead_df, temp_df], ignore_index=True)  #create dictionary with the return period
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# C:\Users\snn490\AppData\Local\Temp\ipykernel_8016\3364962273.py:177: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   ead_df['overlay_{}'.format(rp)] = ead_df['overlay_{}'.format(rp)].combine_first(ead_df['osm_id'].map(overlay_dict))
# All osm_id columns are equal: True
# These are the damages per return period for secondary
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,204,591.22
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 11,537,564.50
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 161,237,202.74
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 315,797,142.44
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 513,202,602.67
# This is overlay dict for 250 and secondary
# This is overlay dict for 475 and secondary
# This is overlay dict for 975 and secondary
# This is overlay dict for 1500 and secondary
# This is overlay dict for 2475 and secondary
# All osm_id columns are equal: True
# These are the damages per return period for tertiary
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 2,353,240.30
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 14,310,625.37
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 217,038,248.74
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 464,181,561.82
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 748,008,739.42
# This is overlay dict for 250 and tertiary
# This is overlay dict for 475 and tertiary
# This is overlay dict for 975 and tertiary
# This is overlay dict for 1500 and tertiary
# This is overlay dict for 2475 and tertiary
# All osm_id columns are equal: True
# These are the damages per return period for residential
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 2,062,137.53
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 30,634,078.51
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 406,471,999.06
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 911,284,450.22
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,652,649,742.75
# This is overlay dict for 250 and residential
# This is overlay dict for 475 and residential
# This is overlay dict for 975 and residential
# This is overlay dict for 1500 and residential
# This is overlay dict for 2475 and residential
# All osm_id columns are equal: True
# These are the damages per return period for trunk
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,575,441.69
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 5,366,140.44
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 23,852,179.53
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 67,889,122.91
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 187,894,280.42
# This is overlay dict for 250 and trunk
# This is overlay dict for 475 and trunk
# This is overlay dict for 975 and trunk
# This is overlay dict for 1500 and trunk
# This is overlay dict for 2475 and trunk
# No data for trunk_link
# No data for trunk_link
# No data for motorway
# No data for motorway_link
# No data for primary_link
# No data for primary_link
# No data for secondary_link
# No data for secondary_link
# No data for tertiary_link
# No data for road
# No data for road
# All osm_id columns are equal: True
# These are the damages per return period for track
# The damage for a 250 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 4,467,154.28
# The damage for a 475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 21,885,541.91
# The damage for a 975 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 337,397,629.27
# The damage for a 1500 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 746,342,865.94
# The damage for a 2475 year return event following a combination of curves ['E7.11', 'E7.7', 'E7.12']: 1,229,430,631.46
# This is overlay dict for 250 and track
# This is overlay dict for 475 and track
# This is overlay dict for 975 and track
# This is overlay dict for 1500 and track
# This is overlay dict for 2475 and track
# This is the EAD for earthquakes: 10,717,837.920792414
# This is the max EAD for road segment: 378,417.71467656334
# This is the overlay for RP 250 for earthquakes: 711,843.1757698486
# This is the overlay for RP 475 for earthquakes: 2,089,706.7067998901
# This is the overlay for RP 975 for earthquakes: 14,104,480.209719637
# This is the overlay for RP 1500 for earthquakes: 26,316,699.515815083
# This is the overlay for RP 2475 for earthquakes: 39,951,479.66199667
